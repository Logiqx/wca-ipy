# %% [markdown]
# # WCA Results - Future Competitions
# Created by Michael George (AKA Logiqx)
#
# Link: https://www.speedsolving.com/forum/showthread.php?54128-How-fast-are-the-over-40-s-in-competitions

# %%
# from EventsLib import *

# %% [markdown]
# ## Read Known Persons from CSV
#
# Read person data from CSV into memory, prior to processing

# %%
import os, csv, datetime
import urllib.request, ssl
import json
from bs4 import BeautifulSoup

class Person:
    
    def __init__(self, fields):
        """Initialisise the person"""
        
        self.id = fields[0]
        self.name = fields[1]
        self.country = fields[2]
        self.username = fields[3]
        self.usernum = int(fields[4])
        self.ageCategory = int(fields[5])
        self.highlight = fields[6]
        self.userId = fields[7]
        if self.highlight == 'Y':
            self.name = '* ' + self.name + ' *'


    def getWcaLink(self, eventId = None):
        if (eventId):
            link = '<a href="https://www.worldcubeassociation.org/persons/%s#%s">%s</a>' % (self.id, eventId, self.name)
        else:
            link = '<a href="https://www.worldcubeassociation.org/persons/%s">%s</a>' % (self.id, self.name)

        return link


    def getSpeedsolvingLink(self):
        if self.usernum > 0:
            profile = '%s.%d' % (self.username.replace(' ', '-').replace('.', '-').lower(), self.usernum)
            link = '<a href="https://www.speedsolving.com/members/%s">%s</a>' % (profile, self.username)
        else:
            link = ''

        return link


class Competition:
    
    def __init__(self, ageCategory = 40):
        """Initialisise the partial results"""
        
        self.persons = {}
        self.users = {}
        self.attendees = []
        self.ageCategory = ageCategory


    def readPersons(self, basename):
        """Read seniors from CSV into memory"""
        
        self.persons = {}

        # Read rows using the CSV reader
        fn = os.path.join('..', 'data', 'public', basename + '.csv')
        with open(fn, 'r') as f:
            csvReader = csv.reader(f)
            
            # Process each row individually
            for line in csvReader:
                person = Person(line)

                if person.ageCategory >= self.ageCategory and person.id not in self.persons:
                    self.persons[person.id] = person
                    self.users[int(person.userId)] = person


    def getAttendees(self, fields):
        """Download the list of attendees"""

        def parseHtml(st):
            soup = BeautifulSoup(st, "lxml")
            anchors = soup.find_all("a")

            for anchor in anchors:
                href = anchor.get("href")
                if href:
                    personId = ''
                    if 'worldcubeassociation.org/persons/' in href:
                        personId = href[-10:]
                    elif 'worldcubeassociation.org/results/p.php?i=' in href:
                        personId = href[-10:]
                    elif 'cubingchina.com/results/person/' in href:
                        personId = href[-10:]

                    if id and personId in self.persons.keys():
                        self.attendees.append(self.persons[personId])

        def parseJson(st):           
            jsonTxt = response.read().decode('utf-8')
            registrations = json.loads(jsonTxt)

            for registration in registrations:
                userId = registration['user_id']
                if (userId in self.users.keys()):
                    self.attendees.append(self.users[userId])

                    
        self.compId = fields[0]
        self.compName = fields[1]
        self.compCity = fields[2]
        self.compCountry = fields[3]
        self.compWebsite = fields[4]
        self.startDate = fields[5]
        self.endDate = fields[6]       

        self.attendees = []

        comp_url = ''
        if 'zawody4event.pl' in self.compWebsite:
            comp_url = self.compWebsite
        elif 'speedcubing.pl' in self.compWebsite:
            comp_url = self.compWebsite
        elif 'cubingchina.com' in self.compWebsite:
            comp_url = self.compWebsite + '/competitors'
        elif 'cubing-tw.net' in self.compWebsite:
            comp_url = self.compWebsite + '/competitors'
        elif 'cubecomp.de' in self.compWebsite:
            comp_url = self.compWebsite + '/competitors'
        elif 'speedcubing.nz' in self.compWebsite:
            comp_url = self.compWebsite + '/competitors'
        elif 'canadiancubing.com' in self.compWebsite:
            comp_url = self.compWebsite + '/Competitors'
            
        if comp_url:
            req = urllib.request.Request(comp_url, headers={'User-Agent': 'Mozilla'})
            response = urllib.request.urlopen(req)
            parseHtml(response)
         
        else:
            comp_url = "https://www.worldcubeassociation.org/api/v0/competitions/%s/registrations" % self.compId

            req = urllib.request.Request(comp_url, headers={'User-Agent': 'Mozilla'})
            response = urllib.request.urlopen(req)
            parseJson(response)

        # Output status
        print('Processed %s - %d seniors' % (self.compName, len(self.attendees)))


    def listAttendees(self, weekNo):
        """List seniors from memory"""

        if len(self.attendees) > 0:
            link = '<a href="https://www.worldcubeassociation.org/competitions/%s">%s</a>' % (self.compId, self.compName)
            startDate = datetime.datetime.strptime(self.startDate, '%Y-%m-%d')
            endDate = datetime.datetime.strptime(self.endDate, '%Y-%m-%d')
            if startDate.day == endDate.day:
                dates = startDate.strftime('%b %-d, %Y')
            elif startDate.month == endDate.month:
                dates = startDate.strftime('%b %-d') + endDate.strftime(' - %-d, %Y')
            elif startDate.year == endDate.year:
                dates = startDate.strftime('%b %-d') + endDate.strftime(' - %b %-d, %Y')
            else:
                dates = startDate.strftime('%b %-d, %Y') + endDate.strftime(' - %b %-d, %Y')

            if weekNo == 1:
                html = '<details open>\n'
            else:
                html = '<details>\n'
            html += '  <summary>%s - %s, %s - %s</summary>\n' % (link, self.compCity, self.compCountry, dates)
            html += '  <p style="margin-left: 18px">\n'

            count = 0
            for person in sorted(self.attendees, key=lambda person: person.name):
                if count:
                    html += '<br/>\n'

                ageSuffix = ', %d+' % int(person.ageCategory) if int(person.ageCategory) > self.ageCategory else ''
                html += '    %s, %s%s' % (person.getWcaLink(), person.country, ageSuffix)
                if person.usernum > 0:
                    html += ' - %s on Speedsolving.com' % person.getSpeedsolvingLink()
                
                count += 1

            html += '\n'
            html += '  </p>\n'
            html += '</details>\n\n'
        else:
            html = ''
            
        return html

# %% [markdown]
# ## Analyse Competitions
#
# Process the competitions one-by-one

# %%
import datetime

fn = 'Future_Competitions.md'
with open(os.path.join('..', 'templates', fn), 'r') as f:
    html = ''.join(f.readlines())

refreshed = datetime.datetime.now().replace(microsecond=0).isoformat().replace('T', ' ')
html += 'Last refreshed: ' + refreshed + ' (UTC)\n\n'

fn = 'known_senior_details'
competition = Competition()
competition.readPersons(fn)

fn = os.path.join('..', 'data', 'public', 'future_competitions.csv')
with open(fn, 'r') as f:
    csvReader = csv.reader(f)

    prevDate = ''
    weekNo = 0
    for line in csvReader:
        competition.getAttendees(line)

        if len(competition.attendees) > 0:
            endDate = datetime.datetime.strptime(competition.endDate, '%Y-%m-%d')
            endDate += datetime.timedelta(days = 6 - (endDate.weekday() + 6) % 7)
            if endDate != prevDate:
                html += '<h3>%s</h3>\n\n' % endDate.strftime('%b %-d, %Y')
                prevDate = endDate
                weekNo += 1

            html += competition.listAttendees(weekNo)

fn = 'Future_Competitions.md'
with open(os.path.join('..', 'docs', fn), 'w') as f:
    f.write(html)

print('Future Competitions updated!')
# Out:
# Processed CubingUSA Nationals 2019 - 5 seniors
# Processed German Nationals 2019 - 7 seniors
# Processed Breaking Records Huancayo 2019 - 0 seniors
# Processed Colégio Asther Open 2019 - 1 seniors
# Processed Egyptian Championship 2019 - 0 seniors
# Processed Taizhou Open 2019 - 0 seniors
# Processed Tarija Open 2019 - 0 seniors
# Processed CIC Pasto Open 2019 - 0 seniors
# Processed Ha Noi Championship 2019 - 0 seniors
# Processed Horse City 2019 - 0 seniors
# Processed İstanbul Summer 2019 - 0 seniors
# Processed SSL 3 Varberg 2019 - 2 seniors
# Processed Urnieta Open 2019 - 0 seniors
# Processed West Visayas Championship 2019 - 0 seniors
# Processed Baku Summer 2019 - 0 seniors
# Processed Dongguan Summer 2019 - 0 seniors
# Processed Sucursal Del Cielo 2019 - 0 seniors
# Processed Suzhou Open 2019 - 0 seniors
# Processed Michigan 2019 - 1 seniors
# Processed Austin Summer 2019 - 1 seniors
# Processed Los Ángeles al Cubo 2019 - 0 seniors
# Processed Matsu Open 2019 - 0 seniors
# Processed Puget Sound Summer 2019 - 2 seniors
# Processed V ETEC Jacareí Open 2019 - 0 seniors
# Processed Constanta Cube Days 2019 - 0 seniors
# Processed GLS Cup III 2019 - 3 seniors
# Processed Horsham 2019 - 0 seniors
# Processed Jönköping Side Events 2019 - 5 seniors
# Processed LYN Cubing Days 2019 - 0 seniors
# Processed Phoenix Marketcity Cube Challenge 2019 - 1 seniors
# Processed Pre-Nacionales Arequipa 2019 - 1 seniors
# Processed Sens Open 2019 - 3 seniors
# Processed Tagum City Open 2019 - 0 seniors
# Processed Udmurtia Open 2019 - 0 seniors
# Processed Vinnytsia Cube Cup 2019 - 1 seniors
# Processed Wuxi Open 2019 - 0 seniors
# Processed YJ Moscow Special 2019 - 1 seniors
# Processed Cube Camp in Kanazawa 2019 - 3 seniors
# Processed Baoji Open 2019 - 0 seniors
# Processed Independence Cube Open 2019 - 0 seniors
# Processed Jieyang Open 2019 - 0 seniors
# Processed South Luzon Open 2019 - 0 seniors
# Processed Hoogland Open 2019 - 6 seniors
# Processed Indiana 2019 - 2 seniors
# Processed Indonesian Championship 2019 - 1 seniors
# Processed Korean Championship 2019 - 2 seniors
# Processed Peru Nationals 2019 - 2 seniors
# Processed Amatitlán 2019 - 0 seniors
# Processed Fão Cube Open 2019 - 0 seniors
# Processed Gaston Toe Twiddling 2019 - 3 seniors
# Processed Nisei Week 2019 - 0 seniors
# Processed Østerhøj Open 2019 - 0 seniors
# Processed Tchê Math Cube 2019 - 0 seniors
# Processed Urumqi Open 2019 - 0 seniors
# Processed Baia Mare North Open 2019 - 0 seniors
# Processed Brasília Winter 2019 - 1 seniors
# Processed Bursa Summer 2019 - 0 seniors
# Processed Kharkiv Open 2019 - 0 seniors
# Processed Open UTF ao Cubo 2019 - 0 seniors
# Processed Vantaa Back to School 2019 - 1 seniors
# Processed Regionales Medellín 2019 - 0 seniors
# Processed Bay Area Speedcubin' 19 2019 - 1 seniors
# Processed Ningxia Open 2019 - 0 seniors
# Processed Sfax Summer Open 2019 - 0 seniors
# Processed Zhanjiang Open 2019 - 0 seniors
# Processed Festival Cubero Cúbico 2019 - 0 seniors
# Processed Vancouver Big Cubes Open 2019 - 3 seniors
# Processed Ukrainian Nationals 2019 - 1 seniors
# Processed 3x3 Only Minnesota 2019 - 2 seniors
# Processed Back to School Idaho 2019 - 0 seniors
# Processed Cebu Masters 2019 - 0 seniors
# Processed Cubing in the 6ix 2019 - 0 seniors
# Processed Mishawaka Summer 2019 - 1 seniors
# Processed Project Jastrzębie-Zdrój 2019 - 0 seniors
# Processed Quabbin Summer 2019 - 0 seniors
# Processed Speedcubing ESYA 2019 - 0 seniors
# Processed Strathcona 2019 - 0 seniors
# Processed August Bank Holiday Celebration 2019 - 6 seniors
# Processed Bucharest Blind and Stuff 2019 - 0 seniors
# Processed CCC Qualification Saratov 2019 - 1 seniors
# Processed Chelny Summer 2019 - 0 seniors
# Processed Eka Cube Days 2019 - 1 seniors
# Processed Hungarian Summer 2019 - 1 seniors
# Processed Icelandic Nationals 2019 - 0 seniors
# Processed Kursk Open 2019 - 0 seniors
# Processed Sabah Cube Open 2019 - 3 seniors
# Processed Shenzhen Cubing 10th Anniversary 2019 - 1 seniors
# Processed Swisscubing Cup IV 2019 - 0 seniors
# Processed Tajikistan Open 2019 - 0 seniors
# Processed Teresina Open 2019 - 0 seniors
# Processed Xi'an 10th Anniversary 2019 - 0 seniors
# Processed Chennai Cube Open 2019 - 1 seniors
# Processed CinemaCubing San Carlos 2019 - 0 seniors
# Processed Harold Park Classic 2019 - 4 seniors
# Processed HCMC Pro League 2019 - 0 seniors
# Processed Quanzhou Open 2019 - 0 seniors
# Processed Yono Summer 2019 - 8 seniors
# Processed Scuppernong Spectacular 2019 - 1 seniors
# Processed AZCubing Summer 2019 - 2 seniors
# Processed Back to School DFW 2019 - 1 seniors
# Processed Denver Back to School 2019 - 0 seniors
# Processed Please Be Quiet Merdeka 2019 - 0 seniors
# Processed San Diego Summer 2019 - 0 seniors
# Processed Sigulda Open 2019 - 0 seniors
# Processed Bilbao Open 2019 - 2 seniors
# Processed Croatian Nationals 2019 - 0 seniors
# Processed Cubing in Cill Chainnigh 2019 - 1 seniors
# Processed III Barueri Open 2019 - 0 seniors
# Processed Sofia Autumn 2019 - 0 seniors
# Processed ACA League Final 2019 - 0 seniors
# Processed Kansai Summer 2019 - 0 seniors
# Processed FMC North America West 2019 - 0 seniors
# Processed Spokane Summer 2019 - 2 seniors
# Processed Timisoara West Side Open 2019 - 0 seniors
# Processed CCC Qualification Vladivostok 2019 - 0 seniors
# Processed Champagne Open 2019 - 4 seniors
# Processed IndalOpen 2019 - 1 seniors
# Processed Road to IC - Monterotondo 2019 - 2 seniors
# Processed Sandnes Open 2019 - 0 seniors
# Processed Slovakian Open 2019 - 0 seniors
# Processed Swiss Science Open 2019 - 1 seniors
# Processed Xela Open 2019 - 0 seniors
# Processed SacCubing VIII 2019 - 0 seniors
# Processed Danish Open 2019 - 1 seniors
# Processed Battle of Waterloo 2019 - 1 seniors
# Processed Box Hill Big Blind Bonanza 2019 - 0 seniors
# Processed Republica Dominicana Nationals 2019 - 0 seniors
# Processed Rocky The Ram Cubes 2019 - 0 seniors
# Processed Manaus Cubo Plaza Open II 2019 - 2 seniors
# Processed Mental Breakdown Germany 2019 - 1 seniors
# Processed Merdeka Mind Games 2019 - 0 seniors
# Processed Hungarian Open 2019 - 0 seniors
# Processed Berkeley Summer 2019 - 1 seniors
# Processed Gold Coast Spring 2019 - 1 seniors
# Processed III Masovian Open 2019 - 0 seniors
# Processed Resticker Utah 2019 - 0 seniors
# Processed Singapore MentalMatrix Open 2019 - 0 seniors
# Processed Speedcubing Paphos 2019 - 0 seniors
# Processed Dutch Nationals 2019 - 10 seniors
# Processed Monnem City Cubing 2019 - 4 seniors
# Processed Road to IC - Bologna 2019 - 0 seniors
# Processed Schoolmark Open 2019 - 0 seniors
# Processed Shenzhen Open 2019 - 0 seniors
# Processed UPM Open 2019 - 1 seniors
# Processed Philippine Championship 2019 - 0 seniors
# Processed Santa Barbara Fall 2019 - 1 seniors
# Processed Belgian Open 2019 - 2 seniors
# Processed ICHB Back To School 2019 - 0 seniors
# Processed Liechtenstein Open 2019 - 2 seniors
# Processed Prebold Open 2019 - 0 seniors
# Processed Sun City Open 2019 - 0 seniors
# Processed Chilliwack Cubes Fall 2019 - 0 seniors
# Processed Mudd Fall 2019 - 0 seniors
# Processed Road to IC - Montecatini 2019 - 0 seniors
# Processed Altona Algorithms 2019 - 4 seniors
# Processed Bay Area Speedcubin' 20 2019 - 0 seniors
# Processed Beaconhouse Malaysia Cube Open 2019 - 0 seniors
# Processed Bački Petrovac Open 2019 - 0 seniors
# Processed Empire State Fall 2019 - 0 seniors
# Processed Franconia Fall 2019 - 3 seniors
# Processed Pau Open Fast'n Cuber 2019 - 1 seniors
# Processed Reto Chignahuapan 2019 - 0 seniors
# Processed Patagonia Open 2019 - 0 seniors
# Processed Nordic Championship 2019 - 0 seniors
# Processed Oregon State Favorites 2019 - 0 seniors
# Processed Road to IC - Milano 2019 - 1 seniors
# Processed Swisscubing Cup V 2019 - 0 seniors
# Processed Copper Country Cubing Fall 2019 - 0 seniors
# Processed UK Championship 2019 - 8 seniors
# Processed Puzzling Pakenham 2019 - 2 seniors
# Processed German Big Cube Open 2019 - 1 seniors
# Processed Marikina City Open II 2019 - 0 seniors
# Processed Seraing Open 2019 - 0 seniors
# Processed Zhongshan NxN Speedcubing 2019 - 0 seniors
# Processed Italian Championship 2019 - 5 seniors
# Processed Boise 2019 - 0 seniors
# Processed Munich Open 2019 - 1 seniors
# Processed OSU Blind Weekend 2019 - 0 seniors
# Processed Berkeley Fall 2019 - 0 seniors
# Processed Big and Skewb Utah 2019 - 0 seniors
# Processed SnoCo Fall 2019 - 2 seniors
# Processed Nacionales Guatemala 2019 - 0 seniors
# Processed Weston-super-Mare Open 2019 - 0 seniors
# Processed Campeonato Brasileiro 2019 - 2 seniors
# Processed Darwin Open 2019 - 1 seniors
# Processed Quetzal Cubing 2019 - 0 seniors
# Processed Rocky Top 2019 - 0 seniors
# Processed Clact-On Socks Off 2019 - 0 seniors
# Processed Guildford Open 2020 - 0 seniors
# Future Competitions updated!

# %% [markdown]
# ## All Done!
